# %%
import geopandas as gp

# %%
gdf = gp.read_file("889463776079_s/mg_sep2019_integrado/conjunto_de_datos/00a.shp")

# %%
gdf
# Out:
#        OBJECTID         CVEGEO CVE_ENT CVE_MUN CVE_LOC CVE_AGEB  Ambito  \
# 0             1  010010001216A      01     001    0001     216A  Urbana
# 1             2  0100100012649      01     001    0001     2649  Urbana
# 2             3  010010001383A      01     001    0001     383A  Urbana
# 3             4  010010001287A      01     001    0001     287A  Urbana
# 4             5  010010001084A      01     001    0001     084A  Urbana
# ...         ...            ...     ...     ...     ...      ...     ...
# 80197     80198      32057015A      32     057    None     015A   Rural
# 80198     80199      320580034      32     058    None     0034   Rural
# 80199     80200      320580049      32     058    None     0049   Rural
# 80200     80201      320580053      32     058    None     0053   Rural
# 80201     80202      320580068      32     058    None     0068   Rural
#
#          Shape_Leng    Shape_Area  \
# 0       1765.767569  1.807003e+05
# ...

# %%
gdf_drop = gdf.drop(['Ambito','Shape_Leng','Shape_Area','geometry'], axis=1)

# %%
gdf_drop
# Out:
#        OBJECTID         CVEGEO CVE_ENT CVE_MUN CVE_LOC CVE_AGEB
# 0             1  010010001216A      01     001    0001     216A
# 1             2  0100100012649      01     001    0001     2649
# 2             3  010010001383A      01     001    0001     383A
# 3             4  010010001287A      01     001    0001     287A
# 4             5  010010001084A      01     001    0001     084A
# ...         ...            ...     ...     ...     ...      ...
# 80197     80198      32057015A      32     057    None     015A
# 80198     80199      320580034      32     058    None     0034
# 80199     80200      320580049      32     058    None     0049
# 80200     80201      320580053      32     058    None     0053
# 80201     80202      320580068      32     058    None     0068
#
# [80202 rows x 6 columns]

# %%
gdf.to_csv('list_ageb.csv')

# %%
gdf_drop.to_csv('list_ageb_1.csv')
